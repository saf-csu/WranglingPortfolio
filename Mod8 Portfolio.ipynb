# %%
import csv
import matplotlib as mpl
import plotly
import pandas as pd
import sqlite3

# %%
dfapi = pd.read_csv("API_SE.PRM.ENRL_DS2_en_csv_v2_4538564.csv", header=2, low_memory=True)
dfapi
# Out:
#                     Country Name Country Code             Indicator Name  \
# 0                          Aruba          ABW  Primary education, pupils
# 1    Africa Eastern and Southern          AFE  Primary education, pupils
# 2                    Afghanistan          AFG  Primary education, pupils
# 3     Africa Western and Central          AFW  Primary education, pupils
# 4                         Angola          AGO  Primary education, pupils
# ..                           ...          ...                        ...
# 261                       Kosovo          XKX  Primary education, pupils
# 262                  Yemen, Rep.          YEM  Primary education, pupils
# 263                 South Africa          ZAF  Primary education, pupils
# 264                       Zambia          ZMB  Primary education, pupils
# 265                     Zimbabwe          ZWE  Primary education, pupils
#
#     Indicator Code  1960  1961  1962  1963  1964  1965  ...       2013  \
# 0      SE.PRM.ENRL   NaN   NaN   NaN   NaN   NaN   NaN  ...     9803.0
# 1      SE.PRM.ENRL   NaN   NaN   NaN   NaN   NaN   NaN  ...        NaN
# 2      SE.PRM.ENRL   NaN   NaN   NaN   NaN   NaN   NaN  ...  5986268.0
# 3      SE.PRM.ENRL   NaN   NaN   NaN   NaN   NaN   NaN  ...        NaN
# 4      SE.PRM.ENRL   NaN   NaN   NaN   NaN   NaN   NaN  ...        NaN
# ..             ...   ...   ...   ...   ...   ...   ...  ...        ...
# 261    SE.PRM.ENRL   NaN   NaN   NaN   NaN   NaN   NaN  ...        NaN
# 262    SE.PRM.ENRL   NaN   NaN   NaN   NaN   NaN   NaN  ...  3874741.0
# 263    SE.PRM.ENRL   NaN   NaN   NaN   NaN   NaN   NaN  ...  7063849.0
# 264    SE.PRM.ENRL   NaN   NaN   NaN   NaN   NaN   NaN  ...  3075161.0
# 265    SE.PRM.ENRL   NaN   NaN   NaN   NaN   NaN   NaN  ...  2663187.0
#
#           2014       2015       2016       2017       2018       2019  \
# 0       9816.0        NaN        NaN        NaN        NaN        NaN
# 1          NaN        NaN        NaN        NaN        NaN        NaN
# 2    6217756.0  6199329.0  6265011.0  6350404.0  6544906.0  6777785.0
# 3          NaN        NaN        NaN        NaN        NaN        NaN
# 4          NaN  5620915.0        NaN        NaN        NaN        NaN
# ..         ...        ...        ...        ...        ...        ...
# 261        NaN        NaN        NaN        NaN        NaN        NaN
# 262        NaN        NaN  3900134.0        NaN        NaN        NaN
# 263  7195183.0  7555842.0  7569924.0  7582154.0  7568387.0  7688381.0
# 264  3217872.0  3215723.0  3203220.0  3284841.0        NaN        NaN
# 265        NaN  2658415.0  2662010.0  2676485.0  2725970.0  2789692.0
#
#           2020  2021  Unnamed: 66
# 0          NaN   NaN          NaN
# 1          NaN   NaN          NaN
# 2          NaN   NaN          NaN
# 3          NaN   NaN          NaN
# 4          NaN   NaN          NaN
# ..         ...   ...          ...
# 261        NaN   NaN          NaN
# 262        NaN   NaN          NaN
# 263        NaN   NaN          NaN
# 264        NaN   NaN          NaN
# 265  2869735.0   NaN          NaN
#
# [266 rows x 67 columns]

# %%
dfwd =  pd.read_csv("WDIData.csv", header=0, low_memory=True)
dfwd
# Out:
#                        Country Name Country Code  \
# 0       Africa Eastern and Southern          AFE
# 1       Africa Eastern and Southern          AFE
# 2       Africa Eastern and Southern          AFE
# 3       Africa Eastern and Southern          AFE
# 4       Africa Eastern and Southern          AFE
# ...                             ...          ...
# 383567                     Zimbabwe          ZWE
# 383568                     Zimbabwe          ZWE
# 383569                     Zimbabwe          ZWE
# 383570                     Zimbabwe          ZWE
# 383571                     Zimbabwe          ZWE
#
#                                            Indicator Name     Indicator Code  \
# 0       Access to clean fuels and technologies for coo...     EG.CFT.ACCS.ZS
# 1       Access to clean fuels and technologies for coo...  EG.CFT.ACCS.RU.ZS
# 2       Access to clean fuels and technologies for coo...  EG.CFT.ACCS.UR.ZS
# 3                 Access to electricity (% of population)     EG.ELC.ACCS.ZS
# 4       Access to electricity, rural (% of rural popul...  EG.ELC.ACCS.RU.ZS
# ...                                                   ...                ...
# 383567  Women who believe a husband is justified in be...     SG.VAW.REFU.ZS
# 383568  Women who were first married by age 15 (% of w...  SP.M15.2024.FE.ZS
# 383569  Women who were first married by age 18 (% of w...  SP.M18.2024.FE.ZS
# 383570  Women's share of population ages 15+ living wi...  SH.DYN.AIDS.FE.ZS
# 383571  Young people (ages 15-24) newly infected with HIV     SH.HIV.INCD.YG
#
#         1960  1961  1962  1963  1964  1965  ...          2013          2014  \
# 0        NaN   NaN   NaN   NaN   NaN   NaN  ...     16.936004     17.337896
# 1        NaN   NaN   NaN   NaN   NaN   NaN  ...      6.499471      6.680066
# 2        NaN   NaN   NaN   NaN   NaN   NaN  ...     37.855399     38.046781
# 3        NaN   NaN   NaN   NaN   NaN   NaN  ...     31.794160     32.001027
# 4        NaN   NaN   NaN   NaN   NaN   NaN  ...     18.663502     17.633986
# ...      ...   ...   ...   ...   ...   ...  ...           ...           ...
# 383567   NaN   NaN   NaN   NaN   NaN   NaN  ...           NaN           NaN
# 383568   NaN   NaN   NaN   NaN   NaN   NaN  ...           NaN           NaN
# 383569   NaN   NaN   NaN   NaN   NaN   NaN  ...           NaN     33.500000
# 383570   NaN   NaN   NaN   NaN   NaN   NaN  ...     59.100000     59.400000
# 383571   NaN   NaN   NaN   NaN   NaN   NaN  ...  20000.000000  19000.000000
#
#                 2015          2016          2017          2018         2019  \
# 0          17.687093     18.140971     18.491344     18.825520    19.272212
# 1           6.859110      7.016238      7.180364      7.322294     7.517191
# 2          38.326255     38.468426     38.670044     38.722783    38.927016
# 3          33.871910     38.880173     40.261358     43.061877    44.270860
# 4          16.464681     24.531436     25.345111     27.449908    29.641760
# ...              ...           ...           ...           ...          ...
# 383567     14.500000           NaN           NaN           NaN          NaN
# 383568      3.700000           NaN           NaN           NaN     5.418352
# 383569     32.400000           NaN           NaN           NaN    33.658057
# 383570     59.500000     59.700000     59.900000     60.100000    60.300000
# 383571  17000.000000  15000.000000  13000.000000  10000.000000  8600.000000
#
#                2020    2021  Unnamed: 66
# 0         19.628009     NaN          NaN
# 1          7.651598     NaN          NaN
# 2         39.042839     NaN          NaN
# 3         45.803485     NaN          NaN
# 4         30.404935     NaN          NaN
# ...             ...     ...          ...
# 383567          NaN     NaN          NaN
# 383568          NaN     NaN          NaN
# 383569          NaN     NaN          NaN
# 383570    60.500000    60.7          NaN
# 383571  7700.000000  6800.0          NaN
#
# [383572 rows x 67 columns]
